# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.finance import candlestick2_ohlc
from timaker import TiMaker
# %matplotlib inline

# %%
from candles import CR

# %%
data = CR(name = 'AAPL.csv')

# %%
data._read_csvs()
data._run_all()

# %%
data.data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-08-24   94.870003  108.800003   92.000000  103.120003   99.211334
# 2015-08-25  111.110001  111.110001  103.500000  103.739998   99.807816
# 2015-08-26  107.089996  109.889999  105.050003  109.690002  105.532295
# 2015-08-27  112.230003  113.239998  110.019997  112.919998  108.639862
# 2015-08-28  112.169998  113.309998  111.540001  113.290001  108.995834
#
#                Volume  bearish_engulfing  bearish_harami  bearish_kicker  \
# Date
# 2015-08-24  162206300              False           False           False
# 2015-08-25  103601600              False           False           False
# 2015-08-26   96774600              False           False           False
# 2015-08-27   84616100              False           False           False
# 2015-08-28   53164400              False           False           False
#
#             bullish_engulfing      ...         doji  doji_and_near_doji  \
# ...

# %%
data.read_csvs()

# %%
import datetime as datetime
import matplotlib.ticker as ticker

# %%
def plotter(data, pattern_name):
    fig, ax = plt.subplots(figsize=(32,12))
    candlestick2_ohlc(ax,data['Open'],data['High'],data['Low'],data['Close'],width=0.6) 
    plt.vlines(data.index[data[pattern_name]],data.Close.min(), data.Close.max())
    plt.title(pattern_name, fontsize=25)

# %%
d = data.data
d.index = np.arange(len(d))
d=d[:-200]
for pattern_name in d.columns[6:]:
    plotter(d,pattern_name=pattern_name)

# %%
# Out:
# Index(['bearish_engulfing', 'bearish_harami', 'bearish_kicker',
#        'bullish_engulfing', 'bullish_harami', 'bullish_kicker', 'dark_cloud',
#        'doji', 'doji_and_near_doji', 'doji_yesterday', 'evening_star',
#        'hammer', 'hanging_man', 'inverted_hammer', 'morning_star',
#        'pricing_line', 'shooting_star'],
#       dtype='object')
