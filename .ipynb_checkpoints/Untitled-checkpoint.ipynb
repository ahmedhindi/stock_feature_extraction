# %%
import pandas as pd
import numpy as np
import stockstats
import matplotlib.pyplot as plt
from stockstats import StockDataFrame as Sdf
plt.style.use('ggplot')

# %%
data = pd.read_csv('data/output/new_AAPL.csv', index_col=0)

# %%
def contains(df,subset):
        return [col for col in df.columns.str.lower() if subset in col]

# %%
from IPython.display import Image
Image(filename='sample.png')

# %%
tp = data[contains(data,'macd')]
tp.drop(contains(tp,'macdh')[0], axis=1).plot(figsize=(25,4))
tp[contains(tp,'macdh')[0]].plot(kind='bar')

# %%
# a={'figsize':(15,5)}
data[contains(data,'rsi')].plot(figsize=(25,3))

# %%
# data

# %%
data[contains(data,'stocastic')].plot(figsize=(25,3))
data['80'] = 80
data['20'] = 20
data['80'].plot()
data['20'].plot()

# %%
! pip install pandas_talib
# Out:
# Collecting pandas_talib
#   Could not find a version that satisfies the requirement pandas_talib (from versions: )
# No matching distribution found for pandas_talib

# %%
import stockstats
import pandas as pd

# %%
a = stockstats.StockDataFrame.retype(pd.read_csv('data/input/AAPL.csv', index_col=0))

# %%
#MACD, MACD Signal and MACD difference  
def macd(df, n_fast, n_slow):  
    EMAfast = pd.Series(pd.ewma(df['close'], span = n_fast, min_periods = n_slow - 1))  
    EMAslow = pd.Series(pd.ewma(df['close'], span = n_slow, min_periods = n_slow - 1))  
    MACD = pd.Series(EMAfast - EMAslow, name = 'MACD_' + str(n_fast) + '_' + str(n_slow))  
    MACDsign = pd.Series(pd.ewma(MACD, span = 9, min_periods = 8), name = 'MACDsign_' + str(n_fast) + '_' + str(n_slow))  
    MACDdiff = pd.Series(MACD - MACDsign, name = 'MACDdiff_' + str(n_fast) + '_' + str(n_slow))  
    df = df.join(MACD)  
    df = df.join(MACDsign)  
    df = df.join(MACDdiff)  
    return df

# %%
b = macd(a, 12, 26)
# Out:
# /home/ahmed/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=12,min_periods=25,adjust=True,ignore_na=False).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ahmed/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=26,min_periods=25,adjust=True,ignore_na=False).mean()
#   after removing the cwd from sys.path.
# /home/ahmed/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=9,min_periods=8,adjust=True,ignore_na=False).mean()

# %%
b.columns = b.columns.str.lower()

# %%
b[contains(b,'macd')].drop('macddiff_12_26',axis=1).plot(figsize=(20,5))
b['macddiff_12_26'].plot(kind='bar')

# %%
# %matplotlib inline

# %%
tp = data[contains(data,'macd')]
tp.drop(contains(tp,'macdh')[0], axis=1).plot(figsize=(25,4))
tp[contains(tp,'macdh')[0]].plot(kind='bar')

# %%
b
# Out:
#                   open        high         low       close   adj close  \
# Date
# 2016-09-26  111.639999  113.389999  111.550003  112.879997  110.923363
# 2016-09-27  113.000000  113.180000  112.339996  113.089996  111.129723
# 2016-09-28  113.690002  114.639999  113.430000  113.949997  111.974823
# 2016-09-29  113.160004  113.800003  111.800003  112.180000  110.235504
# 2016-09-30  112.459999  113.370003  111.800003  113.050003  111.090431
# 2016-10-03  112.709999  113.050003  112.279999  112.519997  110.569603
# 2016-10-04  113.059998  114.309998  112.629997  113.000000  111.041290
# 2016-10-05  113.400002  113.660004  112.690002  113.050003  111.090431
# 2016-10-06  113.699997  114.339996  113.129997  113.889999  111.915863
# 2016-10-07  114.309998  114.559998  113.510002  114.059998  112.082916
# 2016-10-10  115.019997  116.750000  114.720001  116.050003  114.038429
# 2016-10-11  117.699997  118.690002  116.199997  116.300003  114.284088
# 2016-10-12  117.349998  117.980003  116.750000  117.339996  115.306061
# 2016-10-13  116.790001  117.440002  115.720001  116.980003  114.952301
# 2016-10-14  117.879997  118.169998  117.129997  117.629997  115.591034
# 2016-10-17  117.330002  117.839996  116.779999  117.550003  115.512428
# 2016-10-18  118.180000  118.209999  117.449997  117.470001  115.433815
# 2016-10-19  117.250000  117.760002  113.800003  117.120003  115.089874
# 2016-10-20  116.860001  117.379997  116.330002  117.059998  115.030914
# 2016-10-21  116.809998  116.910004  116.279999  116.599998  114.578880
# 2016-10-24  117.099998  117.739998  117.000000  117.650002  115.610680
# 2016-10-25  117.949997  118.360001  117.309998  118.250000  116.200294
# 2016-10-26  114.309998  115.699997  113.309998  115.589996  113.586395
# 2016-10-27  115.389999  115.860001  114.099998  114.480003  112.495644
# 2016-10-28  113.870003  115.209999  113.449997  113.720001  111.748817
# 2016-10-31  113.650002  114.230003  113.199997  113.540001  111.571930
# 2016-11-01  113.459999  113.769997  110.529999  111.489998  109.557465
# 2016-11-02  111.400002  112.349998  111.230003  111.589996  109.655731
# 2016-11-03  110.980003  111.459999  109.550003  109.830002  108.480354
# 2016-11-04  108.529999  110.250000  108.110001  108.839996  107.502518
# ...                ...         ...         ...         ...         ...
# 2017-07-11  144.729996  145.850006  144.380005  145.529999  144.960739
# 2017-07-12  145.869995  146.179993  144.820007  145.740005  145.169922
# 2017-07-13  145.500000  148.490005  145.440002  147.770004  147.191986
# 2017-07-14  147.970001  149.330002  147.330002  149.039993  148.457001
# 2017-07-17  148.820007  150.899994  148.570007  149.559998  148.974976
# 2017-07-18  149.199997  150.130005  148.669998  150.080002  149.492950
# 2017-07-19  150.479996  151.419998  149.949997  151.020004  150.429276
# 2017-07-20  151.500000  151.740005  150.190002  150.339996  149.751923
# 2017-07-21  149.990005  150.440002  148.880005  150.270004  149.682205
# 2017-07-24  150.580002  152.440002  149.899994  152.089996  151.495071
# 2017-07-25  151.800003  153.839996  151.800003  152.740005  152.142548
# 2017-07-26  153.350006  153.929993  153.059998  153.460007  152.859726
# 2017-07-27  153.750000  153.990005  147.300003  150.559998  149.971069
# 2017-07-28  149.889999  150.229996  149.190002  149.500000  148.915207
# 2017-07-31  149.899994  150.330002  148.130005  148.729996  148.148224
# 2017-08-01  149.100006  150.220001  148.410004  150.050003  149.463058
# 2017-08-02  159.279999  159.750000  156.160004  157.139999  156.525330
# 2017-08-03  157.050003  157.210007  155.020004  155.570007  154.961472
# 2017-08-04  156.070007  157.399994  155.690002  156.389999  155.778259
# 2017-08-07  157.059998  158.919998  156.669998  158.809998  158.188797
# 2017-08-08  158.600006  161.830002  158.270004  160.080002  159.453827
# 2017-08-09  159.259995  161.270004  159.110001  161.059998  160.429993
# 2017-08-10  159.899994  160.000000  154.630005  155.320007  155.320007
# 2017-08-11  156.600006  158.570007  156.070007  157.479996  157.479996
# 2017-08-14  159.320007  160.210007  158.750000  159.850006  159.850006
# 2017-08-15  160.660004  162.199997  160.139999  161.600006  161.600006
# 2017-08-16  161.940002  162.509995  160.149994  160.949997  160.949997
# 2017-08-17  160.520004  160.710007  157.839996  157.860001  157.860001
# 2017-08-18  157.860001  159.500000  156.720001  157.500000  157.500000
# 2017-08-21  157.500000  157.889999  155.110001  157.210007  157.210007
#
#               volume  macd_12_26  macdsign_12_26  macddiff_12_26
# Date
# 2016-09-26  29869400         NaN             NaN             NaN
# 2016-09-27  24607400         NaN             NaN             NaN
# 2016-09-28  29641100         NaN             NaN             NaN
# 2016-09-29  35887000         NaN             NaN             NaN
# 2016-09-30  36379100         NaN             NaN             NaN
# 2016-10-03  21701800         NaN             NaN             NaN
# 2016-10-04  29736800         NaN             NaN             NaN
# 2016-10-05  21453100         NaN             NaN             NaN
# 2016-10-06  28779300         NaN             NaN             NaN
# 2016-10-07  24358400         NaN             NaN             NaN
# 2016-10-10  36236000         NaN             NaN             NaN
# 2016-10-11  64041000         NaN             NaN             NaN
# 2016-10-12  37586800         NaN             NaN             NaN
# 2016-10-13  35192400         NaN             NaN             NaN
# 2016-10-14  35652200         NaN             NaN             NaN
# 2016-10-17  23624900         NaN             NaN             NaN
# 2016-10-18  24553500         NaN             NaN             NaN
# 2016-10-19  20034600         NaN             NaN             NaN
# 2016-10-20  24125800         NaN             NaN             NaN
# 2016-10-21  23192700         NaN             NaN             NaN
# 2016-10-24  23538700         NaN             NaN             NaN
# 2016-10-25  48129000         NaN             NaN             NaN
# 2016-10-26  66134200         NaN             NaN             NaN
# 2016-10-27  34562000         NaN             NaN             NaN
# 2016-10-28  37861700    0.132063             NaN             NaN
# 2016-10-31  26419400   -0.047586             NaN             NaN
# 2016-11-01  43825800   -0.332311             NaN             NaN
# 2016-11-02  28331700   -0.543295             NaN             NaN
# 2016-11-03  26932600   -0.828466             NaN             NaN
# 2016-11-04  30837000   -1.113377             NaN             NaN
# ...              ...         ...             ...             ...
# 2017-07-11  19781800   -1.310052       -1.507477        0.197425
# 2017-07-12  24884500   -1.139171       -1.433816        0.294645
# 2017-07-13  25199400   -0.830371       -1.313127        0.482756
# 2017-07-14  20132100   -0.477661       -1.146034        0.668373
# 2017-07-17  23793500   -0.154396       -0.947706        0.793311
# 2017-07-18  17868800    0.142116       -0.729742        0.871858
# 2017-07-19  20923000    0.447792       -0.494235        0.942027
# 2017-07-20  17243700    0.627933       -0.269801        0.897735
# 2017-07-21  26252600    0.756330       -0.064575        0.820905
# 2017-07-24  21493200    0.993491        0.147038        0.846453
# 2017-07-25  18853900    1.219832        0.361597        0.858235
# 2017-07-26  15781000    1.440700        0.577418        0.863282
# 2017-07-27  32476300    1.365986        0.735131        0.630855
# 2017-07-28  17213700    1.207324        0.829570        0.377755
# 2017-07-31  19845900    1.007834        0.865223        0.142611
# 2017-08-01  35368600    0.945352        0.881248        0.064103
# 2017-08-02  69936800    1.451209        0.995241        0.455969
# 2017-08-03  27097300    1.705757        1.137344        0.568413
# 2017-08-04  20559900    1.951162        1.300107        0.651055
# 2017-08-07  21870300    2.314244        1.502935        0.811309
# 2017-08-08  36205900    2.673648        1.737077        0.936571
# 2017-08-09  26131500    3.002940        1.990250        1.012690
# 2017-08-10  40804300    2.768819        2.145964        0.622855
# 2017-08-11  26257100    2.726144        2.262000        0.464145
# 2017-08-14  22028200    2.850703        2.379741        0.470963
# 2017-08-15  29465500    3.055407        2.514874        0.540533
# 2017-08-16  27671600    3.129115        2.637722        0.491393
# 2017-08-17  27940600    2.904709        2.691119        0.213589
# 2017-08-18  27428100    2.667072        2.686310       -0.019238
# 2017-08-21  26178400    2.427362        2.634520       -0.207159
#
# [228 rows x 9 columns]

# %%
import pandas as pd
import numpy as np
import stockstats
from stockstats import StockDataFrame as Sdf


class TiMaker():
    def __init__(self, path):
        """
        path: the path of the csv file containing stock data.
        """
        self.features = {
        "Stocastic":['kdjd_5','kdjk_3'],
        "RSI":['rsi_14'],
        "ADX":['adx_15_ema'],
        # "MACD":['macd', 'macds', 'macdh'],
        "BBands":['boll', 'boll_ub', 'boll_lb'],
        "ATR":['atr'],}
        self.path = path
        self.stockdf = None
        self.col_names = None
        self.final_data = None
        self.sma_list = [9,20,50]

    def macd(self, n_fast=12, n_slow=26):
        EMAfast = pd.Series(pd.ewma(self.stockdf['close'], span = n_fast, min_periods = n_slow - 1))
        EMAslow = pd.Series(pd.ewma(self.stockdf['close'], span = n_slow, min_periods = n_slow - 1))
        MACD = pd.Series(EMAfast - EMAslow, name = 'macd_' + str(n_fast) + '_' + str(n_slow))
        MACDsign = pd.Series(pd.ewma(MACD, span = 9, min_periods = 8), name = 'macdsign_' + str(n_fast) + '_' + str(n_slow))
        MACDdiff = pd.Series(MACD - MACDsign, name = 'macddiff_' + str(n_fast) + '_' + str(n_slow))
        self.stockdf[MACD.name] = MACD
        self.stockdf[MACDsign.name] = MACDsign
        self.stockdf[MACDdiff.name] = MACDdiff
        for i in [MACD.name, MACDsign.name, MACDdiff.name]:
            self.col_names.append(i)

    def read_df(self):
        """Read csv stock data and convert it to stock data frame."""
        self.stockdf = Sdf.retype(pd.read_csv('data/input/'+self.path))
        self.col_names = list(self.stockdf.columns)

    def feature_maker(self):
        """Make features"""
        #loop over the keys of the features dict
        for ind in self.features.keys():
            #loop over the commands in the value (list) for the ind key
            for comm in self.features[ind]:
                col_name = str(ind+'_'+comm)
                #append the new features to the col_names list
                self.col_names.append(col_name)
                #creat  new feature as a column in the datafame
                self.stockdf[col_name] = self.stockdf.get(comm)

    def make_final_data(self):
        """The final dataframe."""
        self.final_data = self.stockdf[self.col_names].replace(10.000000,np.nan).dropna()

    def make_smas(self):
        for i in self.sma_list:
            name = str(i)+' sma'
            self.col_names.append(name)
            self.stockdf[name]  = self.stockdf['close'].rolling(i).mean()

    def run_all(self):
        """Run all functions and return the final dataframe."""
        self.read_df()
        self.make_smas()
        self.macd()
        self.feature_maker()
        self.make_final_data()

    def save_df(self):
        """save the df as a csv"""
        self.final_data.to_csv('data/output/new_{}'.format(self.path))

# %%
a = TiMaker('AAPL.csv')

# %%
a.run_all()
# Out:
# /home/ahmed/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=12,min_periods=25,adjust=True,ignore_na=False).mean()
# /home/ahmed/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=26,min_periods=25,adjust=True,ignore_na=False).mean()
# /home/ahmed/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:29: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=9,min_periods=8,adjust=True,ignore_na=False).mean()
# /home/ahmed/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
a.read_df()
a.stockdf.head()
# Out:
#                   open        high         low       close   adj close  \
# date
# 2016-09-26  111.639999  113.389999  111.550003  112.879997  110.923363
# 2016-09-27  113.000000  113.180000  112.339996  113.089996  111.129723
# 2016-09-28  113.690002  114.639999  113.430000  113.949997  111.974823
# 2016-09-29  113.160004  113.800003  111.800003  112.180000  110.235504
# 2016-09-30  112.459999  113.370003  111.800003  113.050003  111.090431
#
#               volume
# date
# 2016-09-26  29869400
# 2016-09-27  24607400
# 2016-09-28  29641100
# 2016-09-29  35887000
# 2016-09-30  36379100

# %%
a.make_smas()

# %%
a.stockdf.head()
# Out:
#                   open        high         low       close   adj close  \
# date
# 2016-09-26  111.639999  113.389999  111.550003  112.879997  110.923363
# 2016-09-27  113.000000  113.180000  112.339996  113.089996  111.129723
# 2016-09-28  113.690002  114.639999  113.430000  113.949997  111.974823
# 2016-09-29  113.160004  113.800003  111.800003  112.180000  110.235504
# 2016-09-30  112.459999  113.370003  111.800003  113.050003  111.090431
#
#               volume  9 sma  20 sma  50 sma
# date
# 2016-09-26  29869400    NaN     NaN     NaN
# 2016-09-27  24607400    NaN     NaN     NaN
# 2016-09-28  29641100    NaN     NaN     NaN
# 2016-09-29  35887000    NaN     NaN     NaN
# 2016-09-30  36379100    NaN     NaN     NaN

# %%
a.macd()
# Out:
# /home/ahmed/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=12,min_periods=25,adjust=True,ignore_na=False).mean()
# /home/ahmed/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=26,min_periods=25,adjust=True,ignore_na=False).mean()
# /home/ahmed/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:29: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=9,min_periods=8,adjust=True,ignore_na=False).mean()

# %%
a.stockdf.head()
# Out:
#                   open        high         low       close   adj close  \
# date
# 2016-09-26  111.639999  113.389999  111.550003  112.879997  110.923363
# 2016-09-27  113.000000  113.180000  112.339996  113.089996  111.129723
# 2016-09-28  113.690002  114.639999  113.430000  113.949997  111.974823
# 2016-09-29  113.160004  113.800003  111.800003  112.180000  110.235504
# 2016-09-30  112.459999  113.370003  111.800003  113.050003  111.090431
#
#               volume  9 sma  20 sma  50 sma  macd_12_26  macdsign_12_26  \
# date
# 2016-09-26  29869400    NaN     NaN     NaN         NaN             NaN
# 2016-09-27  24607400    NaN     NaN     NaN         NaN             NaN
# 2016-09-28  29641100    NaN     NaN     NaN         NaN             NaN
# 2016-09-29  35887000    NaN     NaN     NaN         NaN             NaN
# 2016-09-30  36379100    NaN     NaN     NaN         NaN             NaN
#
#             macddiff_12_26
# date
# 2016-09-26             NaN
# 2016-09-27             NaN
# 2016-09-28             NaN
# 2016-09-29             NaN
# 2016-09-30             NaN

# %%
pd.Series.ewm(span=9,min_periods=8).mean()
pd.ewma(MACD, span = 9, min_periods = 8)

# %%
from timaker import TiMaker

# %%
a = TiMaker('AAPL.csv')

# %%
a.run_all()
# Out:
# /media/ahmed/all my shit/upwork/Akbar/Untitled Folder/stock_feature_extraction/timaker.py:26: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=12,min_periods=25,adjust=True,ignore_na=False).mean()
#   EMAfast = pd.Series(pd.ewma(self.stockdf['close'], span = n_fast, min_periods = n_slow - 1))
# /media/ahmed/all my shit/upwork/Akbar/Untitled Folder/stock_feature_extraction/timaker.py:27: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=26,min_periods=25,adjust=True,ignore_na=False).mean()
#   EMAslow = pd.Series(pd.ewma(self.stockdf['close'], span = n_slow, min_periods = n_slow - 1))
# /media/ahmed/all my shit/upwork/Akbar/Untitled Folder/stock_feature_extraction/timaker.py:29: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=9,min_periods=8,adjust=True,ignore_na=False).mean()
#   MACDsign = pd.Series(pd.ewma(MACD, span = 9, min_periods = 8), name = 'macdsign_' + str(n_fast) + '_' + str(n_slow))
# /home/ahmed/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
data = a.stockdf

# %%
data.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'adj close', 'volume', '9 sma',
#        '20 sma', '50 sma', 'macd_12_26', 'macdsign_12_26', 'macddiff_12_26',
#        'rsv_5', 'kdjk_5', 'kdjd_5', 'Stocastic_kdjd_5', 'rsv_3', 'kdjk_3',
#        'Stocastic_kdjk_3', 'close_-1_s', 'close_-1_d', 'rs_14', 'rsi_14',
#        'RSI_rsi_14', 'high_delta', 'um', 'low_delta', 'dm', 'pdm',
#        'pdm_14_ema', 'pdm_14', 'tr', 'atr_14', 'pdi_14', 'pdi', 'mdm',
#        'mdm_14_ema', 'mdm_14', 'mdi_14', 'mdi', 'dx_14', 'dx', 'dx_6_ema',
#        'adx', 'adx_6_ema', 'adxr', 'adx_15_ema', 'ADX_adx_15_ema',
#        'close_20_sma', 'close_20_mstd', 'boll', 'boll_ub', 'boll_lb',
#        'BBands_boll', 'BBands_boll_ub', 'BBands_boll_lb', 'atr', 'ATR_atr'],
#       dtype='object')

# %%
for i in ['stocastic_kdjd_5', 'stocastic_kdjk_3']:
    print(i in data.columns)
# Out:
# False
# False

# %%
contains(data,'stocastic')
# Out:
# ['stocastic_kdjd_5', 'stocastic_kdjk_3']

# %%
st = data[['Stocastic_kdjd_5', 'Stocastic_kdjk_3']]

st['d>k'] = st.stocastic_kdjd_5 > st.stocastic_kdjk_3

st.drop('d>k', axis=1).plot(figsize=(20,5))

st['shifted'] = st['d>k'].shift(1)

st['shifted'] = st['d>k'].shift(1)
st['cross'] = np.where((st['d>k'] == True) & (st['shifted'] == False), True,False)

st

# %%
st = data[['Stocastic_kdjd_5', 'Stocastic_kdjk_3']]
st['k<d'] = st.stocastic_kdjk_3 <  st.stocastic_kdjd_5
st['shifted'] = st['k<d'].shift(1)
st['SKDT'] = np.where((st['k<d'] == True) & (st['shifted'] == False), True,False)
# -----------
st['k>d'] = st.stocastic_kdjk_3 >  st.stocastic_kdjd_5
st['shifted'] = st['k>d'].shift(1)
st['SKDB'] = np.where((st['k>d'] == True) & (st['shifted'] == False), True,False)
del st['shifted'],st['k>d'], st['k<d']
# ----------
OB = st['stocastic_kdjk_3'] > 80
OB_shifted = OB.shift(1)
mask = np.where((OB==True)&(OB_shifted==False), True,False)
# ---------------
OB = st['stocastic_kdjk_3'] < 80
OB_shifted = OB.shift(1)
mask2 = np.where((OB==True)&(OB_shifted==False), True,False)
#  --------------
OS = st['stocastic_kdjk_3'] > 20
OS_shifted = OS.shift(1)
mask3 = np.where((OS==True)&(OS_shifted==False), True,False)
# ---------------------
OS = st['stocastic_kdjk_3'] < 20
OS_shifted = OS.shift(1)
mask4 = np.where((OS==True)&(OS_shifted==False), True,False)

# %%
OB = st['stocastic_kdjk_3'] > 80
OB_shifted = OB.shift(1)
mask = np.where((OB==True)&(OB_shifted==False), True,False)
# ---------------
OB = st['stocastic_kdjk_3'] < 80
OB_shifted = OB.shift(1)
mask2 = np.where((OB==True)&(OB_shifted==False), True,False)

# %%
OS = st['stocastic_kdjk_3'] > 20
OS_shifted = OS.shift(1)
mask3 = np.where((OS==True)&(OS_shifted==False), True,False)
# ---------------------
OS = st['stocastic_kdjk_3'] < 20
OS_shifted = OS.shift(1)
mask4 = np.where((OS==True)&(OS_shifted==False), True,False)

# %%
import matplotlib.pyplot as plt

# %%
d = data
d.index = np.arange(len(data))

# %%
f = d.index[mask]
g = d.index[mask2]

# %%
d.Stocastic_kdjk_3.plot(figsize=(20,5))
plt.vlines(f,0,100)
plt.hlines(80,0,200)
plt.hlines(20,0,200)

# %%
d.Stocastic_kdjk_3.plot(figsize=(20,5))
plt.vlines(g,0,100)
plt.hlines(80,0,200)
plt.hlines(20,0,200)

# %%
rsi_col = [i for i in data.columns if 'rsi' in i][0]
rsi = data[rsi_col]

# %%
#"RSIUE">>>RSI Upper band entry	
OB = rsi > 70
OB_shifted = OB.shift(1)
data['RSIUE'] = np.where((OB==True)&(OB_shifted==False), True,False)

# %%
# ---------------
# "RSIUX">>>RSI Upper band exit	
OB = rsi < 70
OB_shifted = OB.shift(1)
data['RSIUX'] = np.where((OB==True)&(OB_shifted==False), True,False)
#  --------------
# "RSILE">>>RSI Lower band entry	
OS = rsi < 30
OS_shifted = OS.shift(1)
data['RSILE'] = np.where((OS==True)&(OS_shifted==False), True,False)
# ---------------------
# "RSILX">>>RSI Lower band exit
OS = rsi > 30
OS_shifted = OS.shift(1)
data['RSILX'] = np.where((OS==True)&(OS_shifted==False), True,False)

# %%
a = data[[i for i in data.columns if 'RSI' in i]]

# %%
a.rsi_rsi_14.plot(figsize=(30,5))
plt.hlines(70,a.index.min(),a.index.max(), linestyles='--', alpha=.5)
plt.hlines(30,a.index.min(),a.index.max(), linestyles='--', alpha=.5)
plt.vlines(a.index[a.rsiux],67,73,colors='r', linewidth=3)
plt.vlines(a.index[a.rsiue],67,73,colors='g', linewidth=3)

# %%
a.rsi_rsi_14.plot(figsize=(20,5))
plt.hlines(70,a.index.min(),a.index.max(), linestyles='--', alpha=.5)
plt.hlines(30,a.index.min(),a.index.max(), linestyles='--', alpha=.5)
plt.vlines(a.index[a.rsilx],20,40,colors='r')
plt.vlines(a.index[a.rsile],20,40,colors='g')

# %%
data[[i for i in data.columns if 'sma' in i]]
# Out:
#           9 sma      20 sma      50 sma  close_20_sma
# 0           NaN         NaN         NaN    112.879997
# 1           NaN         NaN         NaN    112.984996
# 2           NaN         NaN         NaN    113.306663
# 3           NaN         NaN         NaN    113.024997
# 4           NaN         NaN         NaN    113.029999
# 5           NaN         NaN         NaN    112.944998
# 6           NaN         NaN         NaN    112.952856
# 7           NaN         NaN         NaN    112.964999
# 8    113.067777         NaN         NaN    113.067777
# 9    113.198888         NaN         NaN    113.166999
# 10   113.527778         NaN         NaN    113.429090
# 11   113.788890         NaN         NaN    113.668333
# 12   114.362222         NaN         NaN    113.950769
# 13   114.798889         NaN         NaN    114.167142
# 14   115.366667         NaN         NaN    114.397999
# 15   115.872223         NaN         NaN    114.595000
# 16   116.363334         NaN         NaN    114.764117
# 17   116.722223         NaN         NaN    114.895000
# 18   117.055556         NaN         NaN    115.008947
# 19   117.116667  115.088500         NaN    115.088500
# 20   117.266667  115.327000         NaN    115.327000
# 21   117.367778  115.585000         NaN    115.585000
# 22   117.213333  115.667000         NaN    115.667000
# 23   116.863334  115.782000         NaN    115.782000
# 24   116.437778  115.815500         NaN    115.815500
# 25   116.001111  115.866500         NaN    115.866500
# 26   115.375555  115.791000         NaN    115.791000
# 27   114.767777  115.718000         NaN    115.718000
# 28   114.015555  115.515000         NaN    115.515000
# 29   113.036666  115.254000         NaN    115.254000
# ..          ...         ...         ...           ...
# 198  144.291109  144.780499  149.327799    144.780499
# 199  144.281109  144.737999  149.310999    144.737999
# 200  144.735555  144.868499  149.316199    144.868499
# 201  145.293332  145.105999  149.355799    145.105999
# 202  145.966665  145.470499  149.416399    145.470499
# 203  146.632221  145.657499  149.438799    145.657499
# 204  147.553333  145.957999  149.398999    145.957999
# 205  148.237778  146.181500  149.325999    146.181500
# 206  148.816667  146.413499  149.266199    146.413499
# 207  149.545556  146.703999  149.228999    146.703999
# 208  150.323334  147.049999  149.161799    147.049999
# 209  150.955556  147.536500  149.116999    147.536500
# 210  151.124446  147.773000  149.018799    147.773000
# 211  151.117779  148.064000  149.003799    148.064000
# 212  150.967778  148.299500  148.927599    148.299500
# 213  150.860001  148.627000  148.867399    148.627000
# 214  151.615556  149.279500  148.930399    149.279500
# 215  152.204446  149.921500  148.965799    149.921500
# 216  152.682224  150.532001  149.026799    150.532001
# 217  153.356667  151.219501  149.125599    151.219501
# 218  154.092222  151.947001  149.254999    151.947001
# 219  155.258889  152.713000  149.402799    152.713000
# 220  155.905557  153.090501  149.453999    153.090501
# 221  156.877779  153.512501  149.539999    153.512501
# 222  157.966668  154.027001  149.628000    154.027001
# 223  158.462224  154.603001  149.781400    154.603001
# 224  159.060001  155.099501  149.911400    155.099501
# 225  159.223335  155.475501  149.961200    155.475501
# 226  159.077779  155.837001  150.011400    155.837001
# 227  158.758891  156.093002  150.176000    156.093002
#
# [228 rows x 4 columns]

# %%
data = pd.read_csv('data/output/new_AAPL.csv', index_col=0)
data.shape
# Out:
# (306, 21)

# %%
_20 = [i for i in data.columns if '20' in i][0]
_50 = [i for i in data.columns if '50' in i][0]
_200 = [i for i in data.columns if '200' in i][0]

# %%
data['20_sma'].plot(figsize=(25,15))
data['50_sma'].plot()
data['200_sma'].plot()
data['close'].plot(linestyle='--')

# %%
# "PC20T" >>>> Price crosses 20DMA from TOP
ps20 = data.close <  data[_20]
ps20shifted = ps20.shift(1)
data['PC20T'] = np.where((ps20 == True) & (ps20shifted == False), True,False)

# %%
data.index = np.arange(len(data))

# %%
data[[_20,'close']].plot(figsize=(25,5))
plt.vlines(data.index[data.PC20T],data.close.min(), data.close.max())

# %%
# "PC20B" >>>> Price crosses 20DMA from Bottom
ps20 = data.close >  data[_20]
ps20shifted = ps20.shift(1)
data['PC20B'] = np.where((ps20 == True) & (ps20shifted == False), True,False)

data[[_20,'close']].plot(figsize=(25,5))
plt.vlines(data.index[data.PC20B],data.close.min(), data.close.max())

# %%
# "PC50T" >>>> Price crosses 50DMA from TOP
ps50 = data.close <  data[_50]
ps50shifted = ps50.shift(1)
data['PC50T'] = np.where((ps50 == True) & (ps50shifted == False), True,False)

data[[_50,'close']].plot(figsize=(25,5))
plt.vlines(data.index[data.PC50T],data.close.min(), data.close.max())

# %%
# "PC50B" >>>> Price crosses 50DMA from Bottom
ps50 = data.close >  data[_50]
ps50shifted = ps50.shift(1)
data['PC20B'] = np.where((ps50 == True) & (ps50shifted == False), True,False)

data[[_50,'close']].plot(figsize=(25,5))
plt.vlines(data.index[data.PC20B],data.close.min(), data.close.max())

# %%
# "PC200T" >>>> Price crosses 200DMA from TOP
ps200 = data.close <  data[_200]
ps200shifted = ps200.shift(1)
data['PC200T'] = np.where((ps200 == True) & (ps200shifted == False), True,False)
print(data.PC200T.sum())
data[[_200,'close']].plot(figsize=(25,5))
plt.vlines(data.index[data.PC200T],data.close.min(), data.close.max())
# Out:
# 0

# %%
# "PC200B" >>>> Price crosses 200DMA from Bottom
ps200 = data.close >  data[_200]
ps200shifted = ps200.shift(1)
data['PC200B'] = np.where((ps200 == True) & (ps200shifted == False), True,False)

data[[_200,'close']].plot(figsize=(25,5))
plt.vlines(data.index[data.PC200B],data.close.min(), data.close.max())

# %%
# "20C50T" >>>> 20DMA crosses 50DMA from Top
_20t_50 = data[_20] <  data[_50]
_20t_50_shifted = _20t_50.shift(1)
data['20C50T'] = np.where((_20t_50 == True) & (_20t_50_shifted == False), True,False)
print(data.PC200T.sum())
data[[_20,_50]].plot(figsize=(25,5))
plt.vlines(data.index[data['20C50T']],data.close.min(), data.close.max())
# Out:
# 0

# %%
# "20C50B" >>>> 20DMA crosses 50DMA from Bottom
_20b_50 = data[_20] >  data[_50]
_20b_50_shifted = _20b_50.shift(1)
data['20C50B'] = np.where((_20b_50 == True) & (_20b_50_shifted == False), True,False)
print(data.PC200T.sum())
data[[_20,_50]].plot(figsize=(25,5))
plt.vlines(data.index[data['20C50B']],data.close.min(), data.close.max())
# Out:
# 0

# %%
# "50C200T" >>>> 50DMA crosses 200DMA from Top

_50t_200 = data[_50] <  data[_200]
_50t_200_shifted = _50t_200.shift(1)
data['50C200T'] = np.where((_50t_200 == True) & (_50t_200_shifted == False), True,False)
print(data.PC200T.sum())
data[[_50,_200]].plot(figsize=(25,5))
plt.vlines(data.index[data['50C200T']],data.close.min(), data.close.max())
# Out:
# 0

# %%
# "50C200B" >>>> 50DMA crosses 200DMA from Bottom
_50b_200 = data[_50] >  data[_200]
_50b_200_shifted = _50b_200.shift(1)
data['50C200B'] = np.where((_50b_200 == True) & (_50b_200_shifted == False), True,False)
print(data.PC200T.sum())
data[[_50,_200]].plot(figsize=(25,5))
plt.vlines(data.index[data['50C200B']],data.close.min(), data.close.max())
# Out:
# 0

# %%
# "20C200T" >>>> 20DMA crosses 200DMA from Top

_20t_200 = data[_20] <  data[_200]
_20t_200_shifted = _20t_200.shift(1)
data['20C200T'] = np.where((_20t_200 == True) & (_20t_200_shifted == False), True,False)
print(data.PC200T.sum())
data[[_20,_200]].plot(figsize=(25,5))
plt.vlines(data.index[data['20C200T']],data.close.min(), data.close.max())
# Out:
# 0

# %%
# "20C200B" >>>> 20DMA crosses 200DMA from Bottom

_20b_200 = data[_20] >  data[_200]
_20b_200_shifted = _20b_200.shift(1)
data['20C200B'] = np.where((_20b_200 == True) & (_20b_200_shifted == False), True,False)
print(data.PC200T.sum())
data[[_20,_200]].plot(figsize=(25,5))
plt.vlines(data.index[data['20C200B']],data.close.min(), data.close.max())
# Out:
# 0
